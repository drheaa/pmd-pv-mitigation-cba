# %%
import Pkg
Pkg.activate(joinpath(@__DIR__, ".."))
Pkg.instantiate()

using PowerModelsDistribution
using DataFrames
using CSV
using Printf
using Parquet
using Statistics

const PMD = PowerModelsDistribution

const PROJECT_ROOT = joinpath(@__DIR__, "..")
const DATA_EXT = joinpath(PROJECT_ROOT, "data", "external")

const NETWORKS_ROOT = joinpath(DATA_EXT, "dsuite_networks_scaled_v1.1")
const PROFILES_ROOT = joinpath(DATA_EXT, "dsuite_load_profiles")  # may contain nested "profiles/"

const OUT_ROOT = joinpath(PROJECT_ROOT, "results", "dataset_analysis")
mkpath(OUT_ROOT)
# Out:
#   Activating project at `/mnt/c/Users/auc009/OneDrive - CSIRO/Documents/power-models-distribution/pmd_pv_experiments`
# "/mnt/c/Users/auc009/OneDrive - CSIRO/Documents/power-models-distribution/pmd_pv_experiments/notebooks/../results/dataset_analysis"
